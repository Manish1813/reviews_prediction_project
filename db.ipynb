# %%
import pymysql

# %%
# !pip install cryptography
# Out:
# Collecting cryptography
#   Downloading cryptography-49.0.0-cp311-abi3-win_amd64.whl.metadata (4.3 kB)
# Collecting cffi>=2.0.0 (from cryptography)
#   Using cached cffi-2.0.0-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography)
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Downloading cryptography-49.0.0-cp311-abi3-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    --------------------------------- ------ 3.1/3.8 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 12.6 MB/s eta 0:00:00
# Using cached cffi-2.0.0-cp312-cp312-win_amd64.whl (183 kB)
# Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: pycparser, cffi, cryptography
# Successfully installed cffi-2.0.0 cryptography-49.0.0 pycparser-3.0
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
 pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in .\restenv\lib\site-packages (24.3.1)
# Collecting pip
#   Downloading pip-26.1.2-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.1.2-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 1.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 2.4 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.3.1
#     Uninstalling pip-24.3.1:
#       Successfully uninstalled pip-24.3.1
# Successfully installed pip-26.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install cryptography
# Out:
# Requirement already satisfied: cryptography in .\restenv\Lib\site-packages (49.0.0)
# Requirement already satisfied: cffi>=2.0.0 in .\restenv\Lib\site-packages (from cryptography) (2.0.0)
# Requirement already satisfied: pycparser in .\restenv\Lib\site-packages (from cffi>=2.0.0->cryptography) (3.0)

# %%
import pymysql
conn=pymysql.connect(user='root',password='Manish@1813',host='localhost')
qur='create database rest_review_db'
mycur=conn.cursor()
mycur.execute(qur)
mycur.close()
conn.close()

# %%
import pymysql
conn=pymysql.connect(user='root',password='Manish@1813',host='localhost',
                             database='rest_review_db')
qur='''create table reviews_table(food VARCHAR(40) PRIMARY KEY ,
       good_review INT,
       bad_review INT,
       customer INT)'''


mycur=conn.cursor()
mycur.execute(qur)
mycur.close()
conn.close()

# %%
foods = ["Idly", "Dosa", "Vada", "Roti", "Meals", "Veg Biryani",
         "Egg Biryani", "Chicken Biryani", "Mutton Biryani",
         "Ice Cream", "Noodles", "Manchooriya", "Orange juice",
         "Apple Juice", "Pineapple juice", "Banana juice"]




for i in foods:
    conn=pymysql.connect(user='root',password='Manish@1813',host='localhost',
                         database='rest_review_db')
    qur='INSERT INTO reviews_table(food,good_review,bad_review,customer) VALUES("%s",%d,%d,%d)'%(i,0,0,0)
    mycur=conn.cursor()
    mycur.execute(qur)
    conn.commit()
    mycur.close()
    conn.close()
