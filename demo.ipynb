# %%
print("Hiiii")
# Out:
# Running cells with 'restenv (3.12.8) (Python 3.12.8)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/reviews_prediction_project/restenv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
print("Hiiii")
